# %%
str = "Hello world"

# %%
str[:4]
# Out:
# 'Hell'

# %%
2**3*3**2
# Out:
# 72

# %%
~~~~5
# Out:
# 5

# %%
if ( 0 ) : print "yes "
# Out:
#   File "<ipython-input-5-8552ac4cf964>", line 1
#     if ( 0 ) : print "yes "
#                           ^
# SyntaxError: invalid syntax

# %%
True = False True = True while True: print(True) break
# Out:
#   File "<ipython-input-6-c1899f607d3e>", line 1
#     True = False True = True while True: print(True) break
#                     ^
# SyntaxError: invalid syntax

# %%
False = True print False
# Out:
#   File "<ipython-input-10-7fb20283707e>", line 1
#     False = True print False
#                      ^
# SyntaxError: invalid syntax

# %%
False = True 
print False
# Out:
#   File "<ipython-input-11-d140e498b187>", line 2
#     print False
#               ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(False)?

# %%
False = True print (False)
# Out:
#   File "<ipython-input-12-8cf40c43b500>", line 1
#     False = True print (False)
#                      ^
# SyntaxError: invalid syntax

# %%
while 100 : print "hello"
# Out:
#   File "<ipython-input-13-3287a1c46a38>", line 1
#     while 100 : print "hello"
#                             ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print("hello")?

# %%
while 100 : print ("hello")
# Out:
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# ...

# %%
while 0 : print "hello"
# Out:
#   File "<ipython-input-15-8ee62d141c45>", line 1
#     while 0 : print "hello"
#                           ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print("hello")?

# %%
while 0 : print ("hello")

# %%
while 0 : print ("hello")

# %%
if 100%000021 == 0 : print ("divisible") else print ("Not divisible")
# Out:
#   File "<ipython-input-18-d3109501d473>", line 1
#     if 100%000021 == 0 : print ("divisible") else print ("Not divisible")
#                 ^
# SyntaxError: invalid token

# %%
i=0 for i < 50 : continue i = i+ 1 print (i)
# Out:
#   File "<ipython-input-19-e626a216a98d>", line 1
#     i=0 for i < 50 : continue i = i+ 1 print (i)
#           ^
# SyntaxError: invalid syntax

# %%
i=0 
for (i < 50) : 
    continue 
    i = i+ 1 
    print (i)
# Out:
#   File "<ipython-input-21-6d19d17ba4c9>", line 2
#     for (i < 50) :
#                  ^
# SyntaxError: invalid syntax

# %%
5<> 4
# Out:
#   File "<ipython-input-22-37c7e3f8a629>", line 1
#     5<> 4
#       ^
# SyntaxError: invalid syntax

# %%
5<>4
# Out:
#   File "<ipython-input-23-0f6edd6bed3a>", line 1
#     5<>4
#       ^
# SyntaxError: invalid syntax

# %%
print (0xA)
# Out:
# 10

# %%
,world"[-1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-84afb6422ee4> in <module>()
# ----> 1 hello[:]+",world"[-1]
#
# NameError: name 'hello' is not defined

# %%
hello[:]+"
# Out:
#   File "<ipython-input-26-609fe41ecd24>", line 1
#     hello[:]+"
#               ^
# SyntaxError: EOL while scanning string literal
